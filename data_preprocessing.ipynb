# %% [markdown]
# <a href="https://colab.research.google.com/github/Victor6b/lab454/blob/main/data_preprocessing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd
import os
import cv2
import math
import random
import matplotlib.pyplot as plt
import shutil
from sklearn.preprocessing import QuantileTransformer
from PIL import Image
import warnings
warnings.filterwarnings("ignore")

# %%
# %cd 'drive/My Drive/Intrusion-Detection-System-Using-CNN-and-Transfer-Learning'
# Out:
# /content/drive/My Drive/Intrusion-Detection-System-Using-CNN-and-Transfer-Learning

# %%
#Read dataset
df=pd.read_csv('data/Car_Hacking_5%.csv')

# %%
df
# Out:
#         CAN ID  DATA[0]  DATA[1]  DATA[2]  DATA[3]  DATA[4]  DATA[5]  DATA[6]  \
# 0         1201       41       39       39       35        0        0        0
# 1          809       64      187      127       20       17       32        0
# 2         1349      216        0        0      136        0        0        0
# 3         1201       41       39       39       35        0        0        0
# 4            2        0        0        0        0        0        3        2
# ...        ...      ...      ...      ...      ...      ...      ...      ...
# 818435     848        5       32       52      104      117        0        0
# 818436    1088      255        0        0        0      255      134        9
# 818437     848        5       32      100      104      117        0        0
# 818438    1349      216       90        0      137        0        0        0
# 818439     790        5       33       48       10       33       30        0
#
#         DATA[7] Label
# 0           154     R
# 1            20     R
# 2             0     R
# 3           154     R
# 4           228     R
# ...         ...   ...
# 818435       12     R
# 818436        0     R
# 818437       92     R
# 818438        0     R
# 818439      111     R
#
# [818440 rows x 10 columns]

# %%
# The labels of the dataset. "R" indicates normal patterns, and there are four types of attack (DoS, fuzzy. gear spoofing, and RPM spoofing zttacks)
df.Label.value_counts()
# Out:
# R        701832
# RPM       32539
# gear      29944
# DoS       29501
# Fuzzy     24624
# Name: Label, dtype: int64

# %%
# Transform all features into the scale of [0,1]
numeric_features = df.dtypes[df.dtypes != 'object'].index
scaler = QuantileTransformer()
df[numeric_features] = scaler.fit_transform(df[numeric_features])

# %%
# Multiply the feature values by 255 to transform them into the scale of [0,255]
df[numeric_features] = df[numeric_features].apply(
    lambda x: (x*255))

# %%
df.describe()
# Out:
#               CAN ID        DATA[0]        DATA[1]        DATA[2]  \
# count  818440.000000  818440.000000  818440.000000  818440.000000
# mean      126.740149     113.749103     107.772016      90.261477
# std        74.148665      90.090361      93.233121     101.333170
# min         0.000000       0.000000       0.000000       0.000000
# 25%        65.345345       0.000000       0.000000       0.000000
# 50%       121.118619     125.585586     114.481982       0.000000
# 75%       189.782282     192.717718     193.611111     201.524024
# max       255.000000     255.000000     255.000000     255.000000
#
#              DATA[3]        DATA[4]        DATA[5]        DATA[6]  \
# count  818440.000000  818440.000000  818440.000000  818440.000000
# mean      109.716536     104.567165     112.935671      84.772815
# std       103.536291      94.969036      91.457921     101.170917
# min         0.000000       0.000000       0.000000       0.000000
# 25%         0.000000       0.000000       0.000000       0.000000
# 50%       130.052553     125.202703     130.180180       0.000000
# 75%       189.527027     191.058559     192.079580     190.548048
# max       255.000000     255.000000     255.000000     255.000000
#
#              DATA[7]
# count  818440.000000
# mean       92.753617
# std        99.949572
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%       189.654655
# max       255.000000

# %%
df0=df[df['Label']=='R'].drop(['Label'],axis=1)
df1=df[df['Label']=='RPM'].drop(['Label'],axis=1)
df2=df[df['Label']=='gear'].drop(['Label'],axis=1)
df3=df[df['Label']=='DoS'].drop(['Label'],axis=1)
df4=df[df['Label']=='Fuzzy'].drop(['Label'],axis=1)

# %%
# Generate 9*9 color images for class 0 (Normal)
count=0
ims = []

image_path = "train/0/"
os.makedirs(image_path)

for i in range(0, len(df0)):
    count=count+1
    if count<=27:
        im=df0.iloc[i].values
        ims=np.append(ims,im)
    else:
        ims=np.array(ims).reshape(9,9,3)
        array = np.array(ims, dtype=np.uint8)
        new_image = Image.fromarray(array)
        new_image.save(image_path+str(i)+'.png')
        count=0
        ims = []

# %%
# Generate 9*9 color images for class 1 (RPM spoofing)
count=0
ims = []

image_path = "train/1/"
os.makedirs(image_path)

for i in range(0, len(df1)):
    count=count+1
    if count<=27:
        im=df1.iloc[i].values
        ims=np.append(ims,im)
    else:
        ims=np.array(ims).reshape(9,9,3)
        array = np.array(ims, dtype=np.uint8)
        new_image = Image.fromarray(array)
        new_image.save(image_path+str(i)+'.png')
        count=0
        ims = []

# %%
# Generate 9*9 color images for class 2 (Gear spoofing)
count=0
ims = []

image_path = "train/2/"
os.makedirs(image_path)

for i in range(0, len(df2)):
    count=count+1
    if count<=27:
        im=df2.iloc[i].values
        ims=np.append(ims,im)
    else:
        ims=np.array(ims).reshape(9,9,3)
        array = np.array(ims, dtype=np.uint8)
        new_image = Image.fromarray(array)
        new_image.save(image_path+str(i)+'.png')
        count=0
        ims = []

# %%
# Generate 9*9 color images for class 3 (DoS attack)
count=0
ims = []

image_path = "train/3/"
os.makedirs(image_path)


for i in range(0, len(df3)):
    count=count+1
    if count<=27:
        im=df3.iloc[i].values
        ims=np.append(ims,im)
    else:
        ims=np.array(ims).reshape(9,9,3)
        array = np.array(ims, dtype=np.uint8)
        new_image = Image.fromarray(array)
        new_image.save(image_path+str(i)+'.png')
        count=0
        ims = []

# %%
# Generate 9*9 color images for class 4 (Fuzzy attack)
count=0
ims = []

image_path = "train/4/"
os.makedirs(image_path)


for i in range(0, len(df4)):
    count=count+1
    if count<=27:
        im=df4.iloc[i].values
        ims=np.append(ims,im)
    else:
        ims=np.array(ims).reshape(9,9,3)
        array = np.array(ims, dtype=np.uint8)
        new_image = Image.fromarray(array)
        new_image.save(image_path+str(i)+'.png')
        count=0
        ims = []

# %%
# Create folders to store images
Train_Dir='./train/'
Val_Dir='./test/'
allimgs=[]
for subdir in os.listdir(Train_Dir):
    for filename in os.listdir(os.path.join(Train_Dir,subdir)):
        filepath=os.path.join(Train_Dir,subdir,filename)
        allimgs.append(filepath)
print(len(allimgs)) # Print the total number of images
# Out:
# 23383

# %%
#split a test set from the dataset, train/test size = 80%/20%
Numbers=len(allimgs)//5 	#size of test set (20%)

def mymovefile(srcfile,dstfile):
    if not os.path.isfile(srcfile):
        print ("%s not exist!"%(srcfile))
    else:
        fpath,fname=os.path.split(dstfile)
        if not os.path.exists(fpath):
            os.makedirs(fpath)
        shutil.move(srcfile,dstfile)
        #print ("move %s -> %s"%(srcfile,dstfile))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-fb72c2cb5dac> in <cell line: 2>()
#       1 #split a test set from the dataset, train/test size = 80%/20%
# ----> 2 Numbers=len(allimgs)//5         #size of test set (20%)
#       3
#       4 def mymovefile(srcfile,dstfile):
#       5     if not os.path.isfile(srcfile):
#
# NameError: name 'allimgs' is not defined

# %%
# The size of test set
Numbers
# Out:
# 4676

# %%
# Create the test set
val_imgs=random.sample(allimgs,Numbers)
for img in val_imgs:
    dest_path=img.replace(Train_Dir,Val_Dir)
    mymovefile(img,dest_path)
print('Finish creating test set')
# Out:
# Finish creating test set

# %%
#resize the images 224*224 for better CNN training
def get_224(folder,dstdir):
    imgfilepaths=[]
    for root,dirs,imgs in os.walk(folder):
        for thisimg in imgs:
            thisimg_path=os.path.join(root,thisimg)
            imgfilepaths.append(thisimg_path)
    for thisimg_path in imgfilepaths:
        dir_name,filename=os.path.split(thisimg_path)
        dir_name=dir_name.replace(folder,dstdir)
        new_file_path=os.path.join(dir_name,filename)
        if not os.path.exists(dir_name):
            os.makedirs(dir_name)
        img=cv2.imread(thisimg_path)
        img=cv2.resize(img,(224,224))
        cv2.imwrite(new_file_path,img)
    print('Finish resizing'.format(folder=folder))

# %%
DATA_DIR_224='./train_224/'
get_224(folder='./train/',dstdir=DATA_DIR_224)
# Out:
# Finish resizing

# %%
DATA_DIR2_224='./test_224/'
get_224(folder='./test/',dstdir=DATA_DIR2_224)
# Out:
# Finish resizing

# %%
# Read the images for each category, the file name may vary (27.png, 83.png...)
img1 = Image.open('./train_224/0/27.png')
img2 = Image.open('./train_224/1/83.png')
img3 = Image.open('./train_224/2/27.png')
img4 = Image.open('./train_224/3/27.png')
img5 = Image.open('./train_224/4/27.png')

plt.figure(figsize=(10, 10))
plt.subplot(1,5,1)
plt.imshow(img1)
plt.title("Normal")
plt.subplot(1,5,2)
plt.imshow(img2)
plt.title("RPM Spoofing")
plt.subplot(1,5,3)
plt.imshow(img3)
plt.title("Gear Spoofing")
plt.subplot(1,5,4)
plt.imshow(img4)
plt.title("DoS Attack")
plt.subplot(1,5,5)
plt.imshow(img5)
plt.title("Fuzzy Attack")
plt.show()  # display it

# %%
# Read the images for each category, the file name may vary (27.png, 83.png...)
img1 = Image.open('./train_Spark_224/0/27.png')
img2 = Image.open('./train_Spark_224/4/83.png')
img3 = Image.open('./train_Spark_224/5/27.png')


plt.figure(figsize=(10, 10))
plt.subplot(1,5,1)
plt.imshow(img1)
plt.title("Normal")
plt.subplot(1,5,2)
plt.imshow(img2)
plt.title("Fuzzy Attack")
plt.subplot(1,5,3)
plt.imshow(img3)
plt.title("Malfunction attack")

plt.show()  # display it
